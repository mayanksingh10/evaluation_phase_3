# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("weather")
df
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1     2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2     2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3     2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4     2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# ...          ...      ...      ...      ...       ...          ...       ...
# 8420  2017-06-21    Uluru      2.8     23.4       0.0          NaN       NaN
# 8421  2017-06-22    Uluru      3.6     25.3       0.0          NaN       NaN
# 8422  2017-06-23    Uluru      5.4     26.9       0.0          NaN       NaN
# 8423  2017-06-24    Uluru      7.8     27.0       0.0          NaN       NaN
# 8424  2017-06-25    Uluru     14.9      NaN       0.0          NaN       NaN
#
#      WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0              W           44.0          W  ...        71.0         22.0
# 1            WNW           44.0        NNW  ...        44.0         25.0
# 2            WSW           46.0          W  ...        38.0         30.0
# 3             NE           24.0         SE  ...        45.0         16.0
# 4              W           41.0        ENE  ...        82.0         33.0
# ...          ...            ...        ...  ...         ...          ...
# 8420           E           31.0         SE  ...        51.0         24.0
# 8421         NNW           22.0         SE  ...        56.0         21.0
# 8422           N           37.0         SE  ...        53.0         24.0
# 8423          SE           28.0        SSE  ...        51.0         24.0
# 8424         NaN            NaN        ESE  ...        62.0         36.0
#
#       Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0          1007.7       1007.1       8.0       NaN     16.9     21.8
# 1          1010.6       1007.8       NaN       NaN     17.2     24.3
# 2          1007.6       1008.7       NaN       2.0     21.0     23.2
# 3          1017.6       1012.8       NaN       NaN     18.1     26.5
# 4          1010.8       1006.0       7.0       8.0     17.8     29.7
# ...           ...          ...       ...       ...      ...      ...
# 8420       1024.6       1020.3       NaN       NaN     10.1     22.4
# 8421       1023.5       1019.1       NaN       NaN     10.9     24.5
# 8422       1021.0       1016.8       NaN       NaN     12.5     26.1
# 8423       1019.4       1016.5       3.0       2.0     15.1     26.0
# 8424       1020.2       1017.9       8.0       8.0     15.0     20.9
#
#       RainToday  RainTomorrow
# 0            No            No
# 1            No            No
# 2            No            No
# 3            No            No
# 4            No            No
# ...         ...           ...
# 8420         No            No
# 8421         No            No
# 8422         No            No
# 8423         No            No
# 8424         No           NaN
#
# [8425 rows x 23 columns]

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3         No
# 2       1007.6       1008.7       NaN       2.0     21.0     23.2         No
# 3       1017.6       1012.8       NaN       NaN     18.1     26.5         No
# 4       1010.8       1006.0       7.0       8.0     17.8     29.7         No
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (8425, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8425 non-null   object
#  1   Location       8425 non-null   object
#  2   MinTemp        8350 non-null   float64
#  3   MaxTemp        8365 non-null   float64
#  4   Rainfall       8185 non-null   float64
#  5   Evaporation    4913 non-null   float64
#  6   Sunshine       4431 non-null   float64
#  7   WindGustDir    7434 non-null   object
#  8   WindGustSpeed  7434 non-null   float64
#  9   WindDir9am     7596 non-null   object
#  10  WindDir3pm     8117 non-null   object
#  11  WindSpeed9am   8349 non-null   float64
#  12  WindSpeed3pm   8318 non-null   float64
#  13  Humidity9am    8366 non-null   float64
#  14  Humidity3pm    8323 non-null   float64
#  15  Pressure9am    7116 non-null   float64
#  16  Pressure3pm    7113 non-null   float64
#  17  Cloud9am       6004 non-null   float64
#  18  Cloud3pm       5970 non-null   float64
#  19  Temp9am        8369 non-null   float64
#  20  Temp3pm        8329 non-null   float64
#  21  RainToday      8185 non-null   object
#  22  RainTomorrow   8186 non-null   object
# dtypes: float64(16), object(7)
# memory usage: 1.5+ MB

# %%
df.describe().T
# Out:
#                 count         mean        std    min      25%     50%     75%  \
# MinTemp        8350.0    13.193305   5.403596   -2.0     9.20    13.3    17.4
# MaxTemp        8365.0    23.859976   6.136408    8.2    19.30    23.3    28.0
# Rainfall       8185.0     2.805913  10.459379    0.0     0.00     0.0     1.0
# Evaporation    4913.0     5.389395   5.044484    0.0     2.60     4.6     7.0
# Sunshine       4431.0     7.632205   3.896235    0.0     4.75     8.7    10.7
# WindGustSpeed  7434.0    40.174469  14.665721    7.0    30.00    39.0    50.0
# WindSpeed9am   8349.0    13.847646  10.174579    0.0     6.00    13.0    20.0
# WindSpeed3pm   8318.0    18.533662   9.766986    0.0    11.00    19.0    24.0
# Humidity9am    8366.0    67.822496  16.833283   10.0    56.00    68.0    80.0
# Humidity3pm    8323.0    51.249790  18.423774    6.0    39.00    51.0    63.0
# Pressure9am    7116.0  1017.640233   6.828699  989.8  1013.00  1017.7  1022.3
# Pressure3pm    7113.0  1015.236075   6.766681  982.9  1010.40  1015.3  1019.8
# Cloud9am       6004.0     4.566622   2.877658    0.0     1.00     5.0     7.0
# Cloud3pm       5970.0     4.503183   2.731659    0.0     2.00     5.0     7.0
# Temp9am        8369.0    17.762015   5.627035    1.9    13.80    17.8    21.9
# Temp3pm        8329.0    22.442934   5.980020    7.3    18.00    21.9    26.4
#
#                   max
# MinTemp          28.5
# MaxTemp          45.5
# Rainfall        371.0
# Evaporation     145.0
# Sunshine         13.9
# WindGustSpeed   107.0
# WindSpeed9am     63.0
# WindSpeed3pm     83.0
# Humidity9am     100.0
# Humidity3pm      99.0
# Pressure9am    1039.0
# Pressure3pm    1036.0
# Cloud9am          8.0
# Cloud3pm          8.0
# Temp9am          39.4
# Temp3pm          44.1

# %%
#checking of null values

# %%
df.isnull().sum()
# Out:
# Date                0
# Location            0
# MinTemp            75
# MaxTemp            60
# Rainfall          240
# Evaporation      3512
# Sunshine         3994
# WindGustDir       991
# WindGustSpeed     991
# WindDir9am        829
# WindDir3pm        308
# WindSpeed9am       76
# WindSpeed3pm      107
# Humidity9am        59
# Humidity3pm       102
# Pressure9am      1309
# Pressure3pm      1312
# Cloud9am         2421
# Cloud3pm         2455
# Temp9am            56
# Temp3pm            96
# RainToday         240
# RainTomorrow      239
# dtype: int64

# %%
#so many null values present in this data
#lets remove it with category and continuos

# %%
cat = [col for col in df.columns if df[col].dtypes=='object']
cont = [col for col in df.columns if df[col].dtypes!='object']

# %%
cat
# Out:
# ['Date',
#  'Location',
#  'WindGustDir',
#  'WindDir9am',
#  'WindDir3pm',
#  'RainToday',
#  'RainTomorrow']

# %%
cont
# Out:
# ['MinTemp',
#  'MaxTemp',
#  'Rainfall',
#  'Evaporation',
#  'Sunshine',
#  'WindGustSpeed',
#  'WindSpeed9am',
#  'WindSpeed3pm',
#  'Humidity9am',
#  'Humidity3pm',
#  'Pressure9am',
#  'Pressure3pm',
#  'Cloud9am',
#  'Cloud3pm',
#  'Temp9am',
#  'Temp3pm']

# %%
df['Date'].fillna(df['Date'].mode(),inplace=True)

# %%
df['Location'].fillna(df['Location'].mode(),inplace=True)

# %%
df['WindGustDir'].fillna(df['WindGustDir'].mode(),inplace=True)

# %%
df['WindDir9am'].fillna(df['WindDir9am'].mode(),inplace=True)

# %%
df['WindDir3pm'].fillna(df['WindDir3pm'].mode(),inplace=True)

# %%
df['RainToday'].fillna(df['RainToday'].mode(),inplace=True)

# %%
df['RainTomorrow'].fillna(df['RainTomorrow'].mode(),inplace=True)

# %%
df['MinTemp'].fillna(df['MinTemp'].median(),inplace=True)

# %%
df['MaxTemp'].fillna(df['MaxTemp'].median(),inplace=True)

# %%
df['Rainfall'].fillna(df['Rainfall'].median(),inplace=True)

# %%
df['Evaporation'].fillna(df['Evaporation'].median(),inplace=True)

# %%
df['Sunshine'].fillna(df['Sunshine'].median(),inplace=True)

# %%
df['WindGustSpeed'].fillna(df['WindGustSpeed'].median(),inplace=True)

# %%
df['WindSpeed9am'].fillna(df['WindSpeed9am'].median(),inplace=True)

# %%
df['Humidity3pm'].fillna(df['Humidity3pm'].median(),inplace=True)

# %%
df['Pressure9am'].fillna(df['Pressure9am'].median(),inplace=True)

# %%
df['Pressure3pm'].fillna(df['Pressure3pm'].median(),inplace=True)

# %%
df['Cloud9am'].fillna(df['Cloud9am'].median(),inplace=True)

# %%
df['Cloud3pm'].fillna(df['Cloud3pm'].median(),inplace=True)

# %%
df['Temp9am'].fillna(df['Temp9am'].median(),inplace=True)

# %%
df['Temp3pm'].fillna(df['Temp3pm'].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Date               0
# Location           0
# MinTemp            0
# MaxTemp            0
# Rainfall           0
# Evaporation        0
# Sunshine           0
# WindGustDir      991
# WindGustSpeed      0
# WindDir9am       829
# WindDir3pm       308
# WindSpeed9am       0
# WindSpeed3pm     107
# Humidity9am       59
# Humidity3pm        0
# Pressure9am        0
# Pressure3pm        0
# Cloud9am           0
# Cloud3pm           0
# Temp9am            0
# Temp3pm            0
# RainToday        240
# RainTomorrow     239
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Date               0
# Location           0
# MinTemp            0
# MaxTemp            0
# Rainfall           0
# Evaporation        0
# Sunshine           0
# WindGustDir      991
# WindGustSpeed      0
# WindDir9am       829
# WindDir3pm       308
# WindSpeed9am       0
# WindSpeed3pm     107
# Humidity9am       59
# Humidity3pm        0
# Pressure9am        0
# Pressure3pm        0
# Cloud9am           0
# Cloud3pm           0
# Temp9am            0
# Temp3pm            0
# RainToday        240
# RainTomorrow     239
# dtype: int64

# %%
df.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %%
df['WindGustDir'].fillna(df['WindGustDir'].mode()[0],inplace=True)

# %%
df['WindDir9am'].fillna(df['WindDir9am'].mode()[0],inplace=True)

# %%
df['WindDir3pm'].fillna(df['WindDir3pm'].mode()[0],inplace=True)

# %%
df['RainToday'].fillna(df['RainToday'].mode()[0],inplace=True)

# %%
df['RainTomorrow'].fillna(df['RainTomorrow'].mode()[0],inplace=True)

# %%
df['WindSpeed3pm'].fillna(df['WindSpeed3pm'].median(),inplace=True)

# %%
df['Humidity9am'].fillna(df['Humidity9am'].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %% [markdown]
# all null values are treated

# %% [markdown]
# # univariate analysis

# %%
plt.figure(figsize=(8,6))
sns.countplot(df['RainTomorrow'])
# Out:
# <AxesSubplot:xlabel='RainTomorrow', ylabel='count'>

# %%
df['RainTomorrow'].value_counts()
# Out:
# No     6434
# Yes    1991
# Name: RainTomorrow, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.countplot(df['WindGustDir'])
# Out:
# <AxesSubplot:xlabel='WindGustDir', ylabel='count'>

# %%
df['WindGustDir'].value_counts()
# Out:
# N      1704
# SSE     578
# S       577
# SW      572
# E       557
# WNW     531
# W       507
# WSW     504
# SE      484
# ENE     415
# SSW     396
# NW      383
# NE      353
# NNE     343
# ESE     302
# NNW     219
# Name: WindGustDir, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.countplot(df['WindDir9am'])
# Out:
# <AxesSubplot:xlabel='WindDir9am', ylabel='count'>

# %%
plt.figure(figsize=(8,6))
sns.countplot(df['WindDir3pm'])
# Out:
# <AxesSubplot:xlabel='WindDir3pm', ylabel='count'>

# %%
df['WindDir3pm'].value_counts()
# Out:
# SE     1121
# S       742
# SSE     623
# WSW     580
# NE      544
# N       524
# SW      494
# WNW     487
# NW      468
# W       462
# ESE     462
# E       460
# ENE     417
# SSW     370
# NNE     365
# NNW     306
# Name: WindDir3pm, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.countplot(df['RainToday'])
# Out:
# <AxesSubplot:xlabel='RainToday', ylabel='count'>

# %%
df['RainToday'].value_counts()
# Out:
# No     6435
# Yes    1990
# Name: RainToday, dtype: int64

# %%
plt.figure(figsize=(45,50))
sns.countplot(df['Location'])
# Out:
# <AxesSubplot:xlabel='Location', ylabel='count'>

# %%
df['Location'].value_counts()
# Out:
# Melbourne       1622
# Williamtown     1230
# PerthAirport    1204
# Albury           907
# Newcastle        822
# CoffsHarbour     611
# Brisbane         579
# Penrith          482
# Wollongong       474
# Darwin           250
# Adelaide         205
# Uluru             39
# Name: Location, dtype: int64

# %%
for i in df[cont]:
    plt.figure(figsize=(10,12))
    sns.distplot(df[i],bins=10,color='g')
    plt.title(i)
    plt.show()

# %% [markdown]
# bivariate ANALYSIS

# %%
def stacked_plot(df, group, target):
    fig, ax = plt.subplots(figsize = (6,4))
    temp_df = (df.groupby([group, target]).size()/df.groupby(group)[target].count()).reset_index().pivot(columns=target, index=group, values=0)
    temp_df.plot(kind='bar', stacked=True, ax = ax, color = ["green", "red"])
    ax.xaxis.set_tick_params(rotation=0)
    ax.set_xlabel(group)
    ax.set_ylabel('Rain Tom ')

# %%
plt.figure(figsize=(45,50))
table =pd.crosstab(df['Location'],df['RainTomorrow'])
table.div(table.sum(1),axis=0).plot(kind='bar',stacked=True)
# Out:
# <AxesSubplot:xlabel='Location'>

# %%
sns.scatterplot(df['MinTemp'],df['MaxTemp'],hue='RainTomorrow',data=df)
# Out:
# <AxesSubplot:xlabel='MinTemp', ylabel='MaxTemp'>

# %%
sns.scatterplot(df['Sunshine'],df['Evaporation'],hue='RainTomorrow',data=df)
# Out:
# <AxesSubplot:xlabel='Sunshine', ylabel='Evaporation'>

# %%
sns.scatterplot(df['WindGustSpeed'],df['WindGustDir'],hue='RainTomorrow',data=df)
# Out:
# <AxesSubplot:xlabel='WindGustSpeed', ylabel='WindGustDir'>

# %%
sns.scatterplot(df['WindSpeed9am'],df['WindDir9am'],hue='RainTomorrow',data=df)
# Out:
# <AxesSubplot:xlabel='WindSpeed9am', ylabel='WindDir9am'>

# %%
sns.scatterplot(df['WindSpeed3pm'],df['WindDir3pm'],hue='RainTomorrow',data=df)
# Out:
# <AxesSubplot:xlabel='WindSpeed3pm', ylabel='WindDir3pm'>

# %%
sns.scatterplot(df['Humidity3pm'],df['Humidity9am'],hue='RainTomorrow',data=df)
# Out:
# <AxesSubplot:xlabel='Humidity3pm', ylabel='Humidity9am'>

# %%
sns.scatterplot(df['Pressure3pm'],df['Pressure9am'],hue='RainTomorrow',data=df)
# Out:
# <AxesSubplot:xlabel='Pressure3pm', ylabel='Pressure9am'>

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(df['Cloud3pm'],df['Cloud9am'],hue='RainTomorrow',data=df)
# Out:
# <AxesSubplot:xlabel='Cloud3pm', ylabel='Cloud9am'>

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(df['Temp3pm'],df['Temp9am'],hue='RainTomorrow',data=df)
# Out:
# <AxesSubplot:xlabel='Temp3pm', ylabel='Temp9am'>

# %%
df['RainToday'].value_counts()
# Out:
# No     6435
# Yes    1990
# Name: RainToday, dtype: int64

# %%
df.groupby('RainToday')['RainTomorrow'].value_counts()
# Out:
# RainToday  RainTomorrow
# No         No              5390
#            Yes             1045
# Yes        No              1044
#            Yes              946
# Name: RainTomorrow, dtype: int64

# %%
sns.countplot(df['RainToday'],hue=df['RainTomorrow'])
# Out:
# <AxesSubplot:xlabel='RainToday', ylabel='count'>

# %%
max_temp = df['MaxTemp']
min_temp = df['MinTemp']

max_temp.plot(figsize=(12,7), legend=True)
min_temp.plot(figsize=(12,7), color ='r', legend=True)
plt.title('max and min temp')
plt.ylabel('Temperature(*C)')
plt.show()

# %%
df.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %% [markdown]
# # correlation

# %%
df.corr()
# Out:
#                 MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# MinTemp        1.000000  0.717522  0.085765     0.262887  0.031722
# MaxTemp        0.717522  1.000000 -0.087595     0.326713  0.357559
# Rainfall       0.085765 -0.087595  1.000000     0.020252 -0.166957
# Evaporation    0.262887  0.326713  0.020252     1.000000  0.217816
# Sunshine       0.031722  0.357559 -0.166957     0.217816  1.000000
# WindGustSpeed  0.230200  0.139909  0.082628     0.147367 -0.034623
# WindSpeed9am   0.136643  0.013444  0.048726     0.133320 -0.068995
# WindSpeed3pm   0.178137  0.088300  0.021594     0.121595 -0.004683
# Humidity9am   -0.130711 -0.391081  0.227587    -0.235151 -0.316515
# Humidity3pm    0.079143 -0.421952  0.234955    -0.169831 -0.421006
# Pressure9am   -0.429683 -0.325758 -0.069595    -0.177701  0.025163
# Pressure3pm   -0.423261 -0.403283 -0.031261    -0.189711 -0.032167
# Cloud9am       0.078412 -0.255267  0.176615    -0.078895 -0.489100
# Cloud3pm       0.022147 -0.252942  0.142066    -0.119121 -0.511608
# Temp9am        0.887111  0.866085 -0.007356     0.316489  0.219706
# Temp3pm        0.685859  0.974690 -0.090649     0.318211  0.376915
#
#                WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# MinTemp             0.230200      0.136643      0.178137    -0.130711
# MaxTemp             0.139909      0.013444      0.088300    -0.391081
# Rainfall            0.082628      0.048726      0.021594     0.227587
# Evaporation         0.147367      0.133320      0.121595    -0.235151
# Sunshine           -0.034623     -0.068995     -0.004683    -0.316515
# WindGustSpeed       1.000000      0.606090      0.639042    -0.271865
# WindSpeed9am        0.606090      1.000000      0.560340    -0.358391
# WindSpeed3pm        0.639042      0.560340      1.000000    -0.250930
# Humidity9am        -0.271865     -0.358391     -0.250930     1.000000
# Humidity3pm        -0.093637     -0.110545     -0.091056     0.633285
# Pressure9am        -0.407139     -0.175584     -0.252752     0.142861
# Pressure3pm        -0.372553     -0.139429     -0.208694     0.173934
# Cloud9am            0.019763     -0.006931     -0.000171     0.399198
# Cloud3pm            0.070237      0.047359     -0.001803     0.294970
# Temp9am             0.202275      0.109635      0.184061    -0.378343
# Temp3pm             0.102066     -0.002279      0.066078    -0.382542
#
#                Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# MinTemp           0.079143    -0.429683    -0.423261  0.078412  0.022147
# MaxTemp          -0.421952    -0.325758    -0.403283 -0.255267 -0.252942
# Rainfall          0.234955    -0.069595    -0.031261  0.176615  0.142066
# Evaporation      -0.169831    -0.177701    -0.189711 -0.078895 -0.119121
# Sunshine         -0.421006     0.025163    -0.032167 -0.489100 -0.511608
# WindGustSpeed    -0.093637    -0.407139    -0.372553  0.019763  0.070237
# WindSpeed9am     -0.110545    -0.175584    -0.139429 -0.006931  0.047359
# WindSpeed3pm     -0.091056    -0.252752    -0.208694 -0.000171 -0.001803
# Humidity9am       0.633285     0.142861     0.173934  0.399198  0.294970
# Humidity3pm       1.000000     0.001702     0.070454  0.409267  0.420823
# Pressure9am       0.001702     1.000000     0.961435 -0.069128 -0.078967
# Pressure3pm       0.070454     0.961435     1.000000 -0.011209 -0.025561
# Cloud9am          0.409267    -0.069128    -0.011209  1.000000  0.579788
# Cloud3pm          0.420823    -0.078967    -0.025561  0.579788  1.000000
# Temp9am          -0.130350    -0.411125    -0.439673 -0.146649 -0.141417
# Temp3pm          -0.491446    -0.283429    -0.369933 -0.269166 -0.292183
#
#                 Temp9am   Temp3pm
# MinTemp        0.887111  0.685859
# MaxTemp        0.866085  0.974690
# Rainfall      -0.007356 -0.090649
# Evaporation    0.316489  0.318211
# Sunshine       0.219706  0.376915
# WindGustSpeed  0.202275  0.102066
# WindSpeed9am   0.109635 -0.002279
# WindSpeed3pm   0.184061  0.066078
# Humidity9am   -0.378343 -0.382542
# Humidity3pm   -0.130350 -0.491446
# Pressure9am   -0.411125 -0.283429
# Pressure3pm   -0.439673 -0.369933
# Cloud9am      -0.146649 -0.269166
# Cloud3pm      -0.141417 -0.292183
# Temp9am        1.000000  0.834471
# Temp3pm        0.834471  1.000000

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# creating a model to predict if rain will happen tom or not

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8425 non-null   object
#  1   Location       8425 non-null   object
#  2   MinTemp        8425 non-null   float64
#  3   MaxTemp        8425 non-null   float64
#  4   Rainfall       8425 non-null   float64
#  5   Evaporation    8425 non-null   float64
#  6   Sunshine       8425 non-null   float64
#  7   WindGustDir    8425 non-null   object
#  8   WindGustSpeed  8425 non-null   float64
#  9   WindDir9am     8425 non-null   object
#  10  WindDir3pm     8425 non-null   object
#  11  WindSpeed9am   8425 non-null   float64
#  12  WindSpeed3pm   8425 non-null   float64
#  13  Humidity9am    8425 non-null   float64
#  14  Humidity3pm    8425 non-null   float64
#  15  Pressure9am    8425 non-null   float64
#  16  Pressure3pm    8425 non-null   float64
#  17  Cloud9am       8425 non-null   float64
#  18  Cloud3pm       8425 non-null   float64
#  19  Temp9am        8425 non-null   float64
#  20  Temp3pm        8425 non-null   float64
#  21  RainToday      8425 non-null   object
#  22  RainTomorrow   8425 non-null   object
# dtypes: float64(16), object(7)
# memory usage: 1.5+ MB

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          4.6       8.7
# 1  2008-12-02   Albury      7.4     25.1       0.0          4.6       8.7
# 2  2008-12-03   Albury     12.9     25.7       0.0          4.6       8.7
# 3  2008-12-04   Albury      9.2     28.0       0.0          4.6       8.7
# 4  2008-12-05   Albury     17.5     32.3       1.0          4.6       8.7
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       5.0     16.9     21.8         No
# 1       1010.6       1007.8       5.0       5.0     17.2     24.3         No
# 2       1007.6       1008.7       5.0       2.0     21.0     23.2         No
# 3       1017.6       1012.8       5.0       5.0     18.1     26.5         No
# 4       1010.8       1006.0       7.0       8.0     17.8     29.7         No
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
#
# [5 rows x 23 columns]

# %%
yes_rain=df[df['RainTomorrow']=='Yes']
no_rain = df[df['RainTomorrow']=='No']

# %%
yes_rain.shape
# Out:
# (1991, 23)

# %%
no_rain.shape
# Out:
# (6434, 23)

# %%
data= yes_rain.append(no_rain,ignore_index=True)

# %%
data
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     2008-12-09   Albury      9.7     31.9       0.0          4.6       8.7
# 1     2008-12-11   Albury     13.4     30.4       0.0          4.6       8.7
# 2     2008-12-12   Albury     15.9     21.7       2.2          4.6       8.7
# 3     2008-12-13   Albury     15.9     18.6      15.6          4.6       8.7
# 4     2008-12-17   Albury     14.1     20.9       0.0          4.6       8.7
# ...          ...      ...      ...      ...       ...          ...       ...
# 8420  2017-06-21    Uluru      2.8     23.4       0.0          4.6       8.7
# 8421  2017-06-22    Uluru      3.6     25.3       0.0          4.6       8.7
# 8422  2017-06-23    Uluru      5.4     26.9       0.0          4.6       8.7
# 8423  2017-06-24    Uluru      7.8     27.0       0.0          4.6       8.7
# 8424  2017-06-25    Uluru     14.9     23.3       0.0          4.6       8.7
#
#      WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0            NNW           80.0         SE  ...        42.0          9.0
# 1              N           30.0        SSE  ...        48.0         22.0
# 2            NNE           31.0         NE  ...        89.0         91.0
# 3              W           61.0        NNW  ...        76.0         93.0
# 4            ENE           22.0        SSW  ...        69.0         82.0
# ...          ...            ...        ...  ...         ...          ...
# 8420           E           31.0         SE  ...        51.0         24.0
# 8421         NNW           22.0         SE  ...        56.0         21.0
# 8422           N           37.0         SE  ...        53.0         24.0
# 8423          SE           28.0        SSE  ...        51.0         24.0
# 8424           N           39.0        ESE  ...        62.0         36.0
#
#       Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0          1008.9       1003.6       5.0       5.0     18.3     30.2
# 1          1011.8       1008.7       5.0       5.0     20.4     28.8
# 2          1010.5       1004.2       8.0       8.0     15.9     17.0
# 3           994.3        993.0       8.0       8.0     17.4     15.8
# 4          1012.2       1010.4       8.0       1.0     17.2     18.1
# ...           ...          ...       ...       ...      ...      ...
# 8420       1024.6       1020.3       5.0       5.0     10.1     22.4
# 8421       1023.5       1019.1       5.0       5.0     10.9     24.5
# 8422       1021.0       1016.8       5.0       5.0     12.5     26.1
# 8423       1019.4       1016.5       3.0       2.0     15.1     26.0
# 8424       1020.2       1017.9       8.0       8.0     15.0     20.9
#
#       RainToday  RainTomorrow
# 0            No           Yes
# 1            No           Yes
# 2           Yes           Yes
# 3           Yes           Yes
# 4            No           Yes
# ...         ...           ...
# 8420         No            No
# 8421         No            No
# 8422         No            No
# 8423         No            No
# 8424         No            No
#
# [8425 rows x 23 columns]

# %%
data.shape
# Out:
# (8425, 23)

# %%
data.dropna(inplace=True)

# %%
data.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-09   Albury      9.7     31.9       0.0          4.6       8.7
# 1  2008-12-11   Albury     13.4     30.4       0.0          4.6       8.7
# 2  2008-12-12   Albury     15.9     21.7       2.2          4.6       8.7
# 3  2008-12-13   Albury     15.9     18.6      15.6          4.6       8.7
# 4  2008-12-17   Albury     14.1     20.9       0.0          4.6       8.7
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0         NNW           80.0         SE  ...        42.0          9.0
# 1           N           30.0        SSE  ...        48.0         22.0
# 2         NNE           31.0         NE  ...        89.0         91.0
# 3           W           61.0        NNW  ...        76.0         93.0
# 4         ENE           22.0        SSW  ...        69.0         82.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1008.9       1003.6       5.0       5.0     18.3     30.2         No
# 1       1011.8       1008.7       5.0       5.0     20.4     28.8         No
# 2       1010.5       1004.2       8.0       8.0     15.9     17.0        Yes
# 3        994.3        993.0       8.0       8.0     17.4     15.8        Yes
# 4       1012.2       1010.4       8.0       1.0     17.2     18.1         No
#
#    RainTomorrow
# 0           Yes
# 1           Yes
# 2           Yes
# 3           Yes
# 4           Yes
#
# [5 rows x 23 columns]

# %%
#convert data feature into datetime

# %%
data['Date']=pd.to_datetime(data['Date'])

# %%
data['year']=data['Date'].dt.year

# %%
data['month']=data['Date'].dt.month

# %%
data['day']=data['Date'].dt.day

# %%
data.drop('Date',axis=1,inplace=True)

# %%
data
# Out:
#      Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      Albury      9.7     31.9       0.0          4.6       8.7         NNW
# 1      Albury     13.4     30.4       0.0          4.6       8.7           N
# 2      Albury     15.9     21.7       2.2          4.6       8.7         NNE
# 3      Albury     15.9     18.6      15.6          4.6       8.7           W
# 4      Albury     14.1     20.9       0.0          4.6       8.7         ENE
# ...       ...      ...      ...       ...          ...       ...         ...
# 8420    Uluru      2.8     23.4       0.0          4.6       8.7           E
# 8421    Uluru      3.6     25.3       0.0          4.6       8.7         NNW
# 8422    Uluru      5.4     26.9       0.0          4.6       8.7           N
# 8423    Uluru      7.8     27.0       0.0          4.6       8.7          SE
# 8424    Uluru     14.9     23.3       0.0          4.6       8.7           N
#
#       WindGustSpeed WindDir9am WindDir3pm  ...  Pressure3pm  Cloud9am  \
# 0              80.0         SE         NW  ...       1003.6       5.0
# 1              30.0        SSE        ESE  ...       1008.7       5.0
# 2              31.0         NE        ENE  ...       1004.2       8.0
# 3              61.0        NNW        NNW  ...        993.0       8.0
# 4              22.0        SSW          E  ...       1010.4       8.0
# ...             ...        ...        ...  ...          ...       ...
# 8420           31.0         SE        ENE  ...       1020.3       5.0
# 8421           22.0         SE          N  ...       1019.1       5.0
# 8422           37.0         SE        WNW  ...       1016.8       5.0
# 8423           28.0        SSE          N  ...       1016.5       3.0
# 8424           39.0        ESE        ESE  ...       1017.9       8.0
#
#       Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  year  month  day
# 0          5.0     18.3     30.2         No           Yes  2008     12    9
# 1          5.0     20.4     28.8         No           Yes  2008     12   11
# 2          8.0     15.9     17.0        Yes           Yes  2008     12   12
# 3          8.0     17.4     15.8        Yes           Yes  2008     12   13
# 4          1.0     17.2     18.1         No           Yes  2008     12   17
# ...        ...      ...      ...        ...           ...   ...    ...  ...
# 8420       5.0     10.1     22.4         No            No  2017      6   21
# 8421       5.0     10.9     24.5         No            No  2017      6   22
# 8422       5.0     12.5     26.1         No            No  2017      6   23
# 8423       2.0     15.1     26.0         No            No  2017      6   24
# 8424       8.0     15.0     20.9         No            No  2017      6   25
#
# [8425 rows x 25 columns]

# %%
d1=data

# %%
num=[col for col in data.columns if data[col].dtypes!='O']
num
# Out:
# ['MinTemp',
#  'MaxTemp',
#  'Rainfall',
#  'Evaporation',
#  'Sunshine',
#  'WindGustSpeed',
#  'WindSpeed9am',
#  'WindSpeed3pm',
#  'Humidity9am',
#  'Humidity3pm',
#  'Pressure9am',
#  'Pressure3pm',
#  'Cloud9am',
#  'Cloud3pm',
#  'Temp9am',
#  'Temp3pm',
#  'year',
#  'month',
#  'day']

# %% [markdown]
# # scaling

# %%
v=data[num]

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
scaled=sc.fit_transform(v)

# %% [markdown]
# # multicolinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
VIF=pd.DataFrame()
VIF['features']=v.columns
VIF['vif']=[variance_inflation_factor(scaled,i) for i in range(len(v.columns))]

# %%
VIF
# Out:
#          features        vif
# 0         MinTemp   8.349081
# 1         MaxTemp  26.399870
# 2        Rainfall   1.123506
# 3     Evaporation   1.206551
# 4        Sunshine   1.691703
# 5   WindGustSpeed   2.338946
# 6    WindSpeed9am   2.022681
# 7    WindSpeed3pm   1.927841
# 8     Humidity9am   3.832879
# 9     Humidity3pm   5.473616
# 10    Pressure9am  17.769093
# 11    Pressure3pm  17.484770
# 12       Cloud9am   1.878780
# 13       Cloud3pm   1.789202
# 14        Temp9am  17.569234
# 15        Temp3pm  33.381724
# 16           year   1.122717
# 17          month   1.149124
# 18            day   1.003114

# %%
num.remove('Temp3pm')

# %%
num.remove('Pressure9am')

# %%
num.remove('Temp9am')

# %%
v=data[num]

# %%
sc=StandardScaler()
scaled=sc.fit_transform(v)

# %%
VIF=pd.DataFrame()
VIF['features']=v.columns
VIF['vif']=[variance_inflation_factor(scaled,i) for i in range(len(v.columns))]

# %%
VIF
# Out:
#          features       vif
# 0         MinTemp  4.157943
# 1         MaxTemp  4.982754
# 2        Rainfall  1.115251
# 3     Evaporation  1.204547
# 4        Sunshine  1.690047
# 5   WindGustSpeed  2.273491
# 6    WindSpeed9am  2.002921
# 7    WindSpeed3pm  1.861579
# 8     Humidity9am  2.322058
# 9     Humidity3pm  2.863382
# 10    Pressure3pm  1.436055
# 11       Cloud9am  1.853082
# 12       Cloud3pm  1.773639
# 13           year  1.094952
# 14          month  1.122377
# 15            day  1.001843

# %%
data.drop(['Temp3pm','Temp9am','Pressure9am'],axis=1,inplace=True)

# %%
data.shape
# Out:
# (8425, 22)

# %%
data.head()
# Out:
#   Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0   Albury      9.7     31.9       0.0          4.6       8.7         NNW
# 1   Albury     13.4     30.4       0.0          4.6       8.7           N
# 2   Albury     15.9     21.7       2.2          4.6       8.7         NNE
# 3   Albury     15.9     18.6      15.6          4.6       8.7           W
# 4   Albury     14.1     20.9       0.0          4.6       8.7         ENE
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 0           80.0         SE         NW  ...         42.0          9.0
# 1           30.0        SSE        ESE  ...         48.0         22.0
# 2           31.0         NE        ENE  ...         89.0         91.0
# 3           61.0        NNW        NNW  ...         76.0         93.0
# 4           22.0        SSW          E  ...         69.0         82.0
#
#    Pressure3pm  Cloud9am  Cloud3pm  RainToday  RainTomorrow  year month  day
# 0       1003.6       5.0       5.0         No           Yes  2008    12    9
# 1       1008.7       5.0       5.0         No           Yes  2008    12   11
# 2       1004.2       8.0       8.0        Yes           Yes  2008    12   12
# 3        993.0       8.0       8.0        Yes           Yes  2008    12   13
# 4       1010.4       8.0       1.0         No           Yes  2008    12   17
#
# [5 rows x 22 columns]

# %% [markdown]
# # outliers

# %%
for i in num:
    sns.boxplot(data[i])
    plt.show()

# %%
sns.distplot(data['Rainfall'])
# Out:
# <AxesSubplot:xlabel='Rainfall', ylabel='Density'>

# %%
data[num].skew()
# Out:
# MinTemp          -0.090519
# MaxTemp           0.382572
# Rainfall         13.200523
# Evaporation      14.064000
# Sunshine         -1.189333
# WindGustSpeed     0.786153
# WindSpeed9am      0.962761
# WindSpeed3pm      0.492365
# Humidity9am      -0.256965
# Humidity3pm       0.118776
# Pressure3pm      -0.015018
# Cloud9am         -0.514801
# Cloud3pm         -0.457713
# year              0.418663
# month             0.039388
# day               0.004260
# dtype: float64

# %%
for i in num:
    IQR=data[i].quantile(.75)-data[i].quantile(.25)
    lower=data[i].quantile(.25)-(1.5 * IQR)
    upper=data[i].quantile(.75)+(1.5*IQR)
    data[i]=np.where(data[i]<lower,lower,data[i])
    data[i]=np.where(data[i]>upper,upper,data[i])

# %%
for i in num:
    sns.boxplot(data[i])
    plt.show()

# %%
data[num].skew()
# Out:
# MinTemp         -0.090519
# MaxTemp          0.360915
# Rainfall         1.189119
# Evaporation      0.062973
# Sunshine        -0.110856
# WindGustSpeed    0.539607
# WindSpeed9am     0.739837
# WindSpeed3pm     0.332888
# Humidity9am     -0.241260
# Humidity3pm      0.118776
# Pressure3pm      0.009366
# Cloud9am        -0.514801
# Cloud3pm        -0.457713
# year             0.418663
# month            0.039388
# day              0.004260
# dtype: float64

# %%
#skewness and outliers are removed

# %%
from sklearn.preprocessing import power_transform

# %%
sc=StandardScaler()

# %%
for i in num:
    trans = power_transform(data[num])
    data[i]=sc.fit_transform(trans)

# %%
data.head()
# Out:
#   Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0   Albury -0.647237 -0.660478 -0.660478    -0.660478 -0.660478         NNW
# 1   Albury  0.040870  0.016441  0.016441     0.016441  0.016441           N
# 2   Albury  0.504474  0.488017  0.488017     0.488017  0.488017         NNE
# 3   Albury  0.504474  0.488017  0.488017     0.488017  0.488017           W
# 4   Albury  0.170776  0.147357  0.147357     0.147357  0.147357         ENE
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 0      -0.660478         SE         NW  ...    -0.660478    -0.660478
# 1       0.016441        SSE        ESE  ...     0.016441     0.016441
# 2       0.488017         NE        ENE  ...     0.488017     0.488017
# 3       0.488017        NNW        NNW  ...     0.488017     0.488017
# 4       0.147357        SSW          E  ...     0.147357     0.147357
#
#    Pressure3pm  Cloud9am  Cloud3pm  RainToday  RainTomorrow      year  \
# 0    -0.660478 -0.660478 -0.660478         No           Yes -0.660478
# 1     0.016441  0.016441  0.016441         No           Yes  0.016441
# 2     0.488017  0.488017  0.488017        Yes           Yes  0.488017
# 3     0.488017  0.488017  0.488017        Yes           Yes  0.488017
# 4     0.147357  0.147357  0.147357         No           Yes  0.147357
#
#       month       day
# 0 -0.660478 -0.660478
# 1  0.016441  0.016441
# 2  0.488017  0.488017
# 3  0.488017  0.488017
# 4  0.147357  0.147357
#
# [5 rows x 22 columns]

# %% [markdown]
# # encoding

# %%
data.head()
# Out:
#   Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0   Albury -0.647237 -0.660478 -0.660478    -0.660478 -0.660478         NNW
# 1   Albury  0.040870  0.016441  0.016441     0.016441  0.016441           N
# 2   Albury  0.504474  0.488017  0.488017     0.488017  0.488017         NNE
# 3   Albury  0.504474  0.488017  0.488017     0.488017  0.488017           W
# 4   Albury  0.170776  0.147357  0.147357     0.147357  0.147357         ENE
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 0      -0.660478         SE         NW  ...    -0.660478    -0.660478
# 1       0.016441        SSE        ESE  ...     0.016441     0.016441
# 2       0.488017         NE        ENE  ...     0.488017     0.488017
# 3       0.488017        NNW        NNW  ...     0.488017     0.488017
# 4       0.147357        SSW          E  ...     0.147357     0.147357
#
#    Pressure3pm  Cloud9am  Cloud3pm  RainToday  RainTomorrow      year  \
# 0    -0.660478 -0.660478 -0.660478         No           Yes -0.660478
# 1     0.016441  0.016441  0.016441         No           Yes  0.016441
# 2     0.488017  0.488017  0.488017        Yes           Yes  0.488017
# 3     0.488017  0.488017  0.488017        Yes           Yes  0.488017
# 4     0.147357  0.147357  0.147357         No           Yes  0.147357
#
#       month       day
# 0 -0.660478 -0.660478
# 1  0.016441  0.016441
# 2  0.488017  0.488017
# 3  0.488017  0.488017
# 4  0.147357  0.147357
#
# [5 rows x 22 columns]

# %%
df2=data[['Location','WindGustDir','WindDir9am','WindDir3pm','RainTomorrow']]

# %%
df2
# Out:
#      Location WindGustDir WindDir9am WindDir3pm RainTomorrow
# 0      Albury         NNW         SE         NW          Yes
# 1      Albury           N        SSE        ESE          Yes
# 2      Albury         NNE         NE        ENE          Yes
# 3      Albury           W        NNW        NNW          Yes
# 4      Albury         ENE        SSW          E          Yes
# ...       ...         ...        ...        ...          ...
# 8420    Uluru           E         SE        ENE           No
# 8421    Uluru         NNW         SE          N           No
# 8422    Uluru           N         SE        WNW           No
# 8423    Uluru          SE        SSE          N           No
# 8424    Uluru           N        ESE        ESE           No
#
# [8425 rows x 5 columns]

# %%
import numpy as np

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
df2
# Out:
#      Location WindGustDir WindDir9am WindDir3pm RainTomorrow
# 0      Albury         NNW         SE         NW          Yes
# 1      Albury           N        SSE        ESE          Yes
# 2      Albury         NNE         NE        ENE          Yes
# 3      Albury           W        NNW        NNW          Yes
# 4      Albury         ENE        SSW          E          Yes
# ...       ...         ...        ...        ...          ...
# 8420    Uluru           E         SE        ENE           No
# 8421    Uluru         NNW         SE          N           No
# 8422    Uluru           N         SE        WNW           No
# 8423    Uluru          SE        SSE          N           No
# 8424    Uluru           N        ESE        ESE           No
#
# [8425 rows x 5 columns]

# %%
df2['RainTomorrow'].replace('No',0,inplace=True)
df2['RainTomorrow'].replace('Yes',1,inplace=True)

# %%
df2
# Out:
#      Location WindGustDir WindDir9am WindDir3pm  RainTomorrow
# 0      Albury         NNW         SE         NW             1
# 1      Albury           N        SSE        ESE             1
# 2      Albury         NNE         NE        ENE             1
# 3      Albury           W        NNW        NNW             1
# 4      Albury         ENE        SSW          E             1
# ...       ...         ...        ...        ...           ...
# 8420    Uluru           E         SE        ENE             0
# 8421    Uluru         NNW         SE          N             0
# 8422    Uluru           N         SE        WNW             0
# 8423    Uluru          SE        SSE          N             0
# 8424    Uluru           N        ESE        ESE             0
#
# [8425 rows x 5 columns]

# %%
ordinal_label = {k: i for i, k in enumerate(df2['Location'].unique(), 0)}
df2['Location'] = df2['Location'].map(ordinal_label)

# %%
ordinal_label = {k: i for i, k in enumerate(df2['WindDir9am'].unique(), 0)}
df2['WindDir9am'] = df2['WindDir9am'].map(ordinal_label)

# %%
ordinal_label = {k: i for i, k in enumerate(df2['WindDir3pm'].unique(), 0)}
df2['WindDir3pm'] = df2['WindDir3pm'].map(ordinal_label)

# %%
ordinal_label = {k: i for i, k in enumerate(df2['WindGustDir'].unique(), 0)}
df2['WindGustDir'] = df2['WindGustDir'].map(ordinal_label)

# %%
df2
# Out:
#       Location  WindGustDir  WindDir9am  WindDir3pm  RainTomorrow
# 0            0            0           0           0             1
# 1            0            1           1           1             1
# 2            0            2           2           2             1
# 3            0            3           3           3             1
# 4            0            4           4           4             1
# ...        ...          ...         ...         ...           ...
# 8420        11           12           0           2             0
# 8421        11            0           0           9             0
# 8422        11            1           0           5             0
# 8423        11            7           1           9             0
# 8424        11            1           7           1             0
#
# [8425 rows x 5 columns]

# %%
inp = df2.drop('RainTomorrow',axis=1)
out=df2['RainTomorrow']

# %%
from sklearn.feature_selection import chi2
f_p_values=chi2(inp,out)

# %%
f_p_values
# Out:
# (array([30.79933399,  0.93898013, 24.98986604,  0.90535298]),
#  array([2.86136050e-08, 3.32540263e-01, 5.76324367e-07, 3.41350425e-01]))

# %%
p_values=pd.Series(f_p_values[1])
p_values.index=inp.columns
p_values
# Out:
# Location       2.861361e-08
# WindGustDir    3.325403e-01
# WindDir9am     5.763244e-07
# WindDir3pm     3.413504e-01
# dtype: float64

# %%
p_values.plot.bar()
# Out:
# <AxesSubplot:>

# %%
data.drop('WindDir3pm',axis=1)
# Out:
#      Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0      Albury -0.647237 -0.660478 -0.660478    -0.660478 -0.660478
# 1      Albury  0.040870  0.016441  0.016441     0.016441  0.016441
# 2      Albury  0.504474  0.488017  0.488017     0.488017  0.488017
# 3      Albury  0.504474  0.488017  0.488017     0.488017  0.488017
# 4      Albury  0.170776  0.147357  0.147357     0.147357  0.147357
# ...       ...       ...       ...       ...          ...       ...
# 8420    Uluru -1.940165 -1.884216 -1.884216    -1.884216 -1.884216
# 8421    Uluru -1.789282 -1.743704 -1.743704    -1.743704 -1.743704
# 8422    Uluru -1.450956 -1.426689 -1.426689    -1.426689 -1.426689
# 8423    Uluru -1.001727 -1.001001 -1.001001    -1.001001 -1.001001
# 8424    Uluru  0.319146  0.298099  0.298099     0.298099  0.298099
#
#      WindGustDir  WindGustSpeed WindDir9am  WindSpeed9am  ...  Humidity9am  \
# 0            NNW      -0.660478         SE     -0.660478  ...    -0.660478
# 1              N       0.016441        SSE      0.016441  ...     0.016441
# 2            NNE       0.488017         NE      0.488017  ...     0.488017
# 3              W       0.488017        NNW      0.488017  ...     0.488017
# 4            ENE       0.147357        SSW      0.147357  ...     0.147357
# ...          ...            ...        ...           ...  ...          ...
# 8420           E      -1.884216         SE     -1.884216  ...    -1.884216
# 8421         NNW      -1.743704         SE     -1.743704  ...    -1.743704
# 8422           N      -1.426689         SE     -1.426689  ...    -1.426689
# 8423          SE      -1.001001        SSE     -1.001001  ...    -1.001001
# 8424           N       0.298099        ESE      0.298099  ...     0.298099
#
#       Humidity3pm  Pressure3pm  Cloud9am  Cloud3pm  RainToday RainTomorrow  \
# 0       -0.660478    -0.660478 -0.660478 -0.660478         No          Yes
# 1        0.016441     0.016441  0.016441  0.016441         No          Yes
# 2        0.488017     0.488017  0.488017  0.488017        Yes          Yes
# 3        0.488017     0.488017  0.488017  0.488017        Yes          Yes
# 4        0.147357     0.147357  0.147357  0.147357         No          Yes
# ...           ...          ...       ...       ...        ...          ...
# 8420    -1.884216    -1.884216 -1.884216 -1.884216         No           No
# 8421    -1.743704    -1.743704 -1.743704 -1.743704         No           No
# 8422    -1.426689    -1.426689 -1.426689 -1.426689         No           No
# 8423    -1.001001    -1.001001 -1.001001 -1.001001         No           No
# 8424     0.298099     0.298099  0.298099  0.298099         No           No
#
#           year     month       day
# 0    -0.660478 -0.660478 -0.660478
# 1     0.016441  0.016441  0.016441
# 2     0.488017  0.488017  0.488017
# 3     0.488017  0.488017  0.488017
# 4     0.147357  0.147357  0.147357
# ...        ...       ...       ...
# 8420 -1.884216 -1.884216 -1.884216
# 8421 -1.743704 -1.743704 -1.743704
# 8422 -1.426689 -1.426689 -1.426689
# 8423 -1.001001 -1.001001 -1.001001
# 8424  0.298099  0.298099  0.298099
#
# [8425 rows x 21 columns]

# %% [markdown]
# # Encoding

# %%
data['RainTomorrow'].replace('No',0,inplace=True)
data['RainTomorrow'].replace('Yes',1,inplace=True)

data['RainToday'].replace('No',0,inplace=True)
data['RainToday'].replace('Yes',1,inplace=True)

# %%
data.head()
# Out:
#   Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0   Albury -0.647237 -0.660478 -0.660478    -0.660478 -0.660478         NNW
# 1   Albury  0.040870  0.016441  0.016441     0.016441  0.016441           N
# 2   Albury  0.504474  0.488017  0.488017     0.488017  0.488017         NNE
# 3   Albury  0.504474  0.488017  0.488017     0.488017  0.488017           W
# 4   Albury  0.170776  0.147357  0.147357     0.147357  0.147357         ENE
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 0      -0.660478         SE         NW  ...    -0.660478    -0.660478
# 1       0.016441        SSE        ESE  ...     0.016441     0.016441
# 2       0.488017         NE        ENE  ...     0.488017     0.488017
# 3       0.488017        NNW        NNW  ...     0.488017     0.488017
# 4       0.147357        SSW          E  ...     0.147357     0.147357
#
#    Pressure3pm  Cloud9am  Cloud3pm  RainToday  RainTomorrow      year  \
# 0    -0.660478 -0.660478 -0.660478          0             1 -0.660478
# 1     0.016441  0.016441  0.016441          0             1  0.016441
# 2     0.488017  0.488017  0.488017          1             1  0.488017
# 3     0.488017  0.488017  0.488017          1             1  0.488017
# 4     0.147357  0.147357  0.147357          0             1  0.147357
#
#       month       day
# 0 -0.660478 -0.660478
# 1  0.016441  0.016441
# 2  0.488017  0.488017
# 3  0.488017  0.488017
# 4  0.147357  0.147357
#
# [5 rows x 22 columns]

# %%
X=data.drop('RainTomorrow',axis=1)
Y=data['RainTomorrow']

# %%
X.shape
# Out:
# (8425, 21)

# %%
Y.shape
# Out:
# (8425,)

# %%
X=pd.get_dummies(X,drop_first=True)

# %%
X.shape
# Out:
# (8425, 73)

# %%
Y.shape
# Out:
# (8425,)

# %% [markdown]
# # smote- balance the data

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE()
x,y=sm.fit_resample(X,Y)

# %%
x.shape
# Out:
# (12868, 73)

# %%
y.shape
# Out:
# (12868,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report

# %%
from sklearn.model_selection import train_test_split

# %%
maxacc=0
maxrs=0
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    lr=LogisticRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxacc:
        maxacc=acc
        maxrs=i

print("r2 score=",maxacc,"random_state",maxrs)
# Out:
# r2 score= 0.764050764050764 random_state 88

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=88)

# %%
lr = LogisticRegression()
gb= GaussianNB()
dtc= DecisionTreeClassifier()
svc=SVC()
rf=RandomForestClassifier()
et=ExtraTreesClassifier()
ada=AdaBoostClassifier()
gbc=GradientBoostingClassifier()
models=[lr,gb,dtc,svc,rf,et,ada,gbc]
for i in models:
    print(i)
    i.fit(x_train,y_train)
    pred=i.predict(x_test)
    print(accuracy_score(y_test,pred))
    print(confusion_matrix(y_test,pred))
    print(classification_report(y_test,pred))
# Out:
# LogisticRegression()
# 0.764050764050764
# [[1594  377]
#  [ 534 1356]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.81      0.78      1971
#            1       0.78      0.72      0.75      1890
#
#     accuracy                           0.76      3861
#    macro avg       0.77      0.76      0.76      3861
# weighted avg       0.77      0.76      0.76      3861
#
# GaussianNB()
# 0.5858585858585859
# [[ 554 1417]
#  [ 182 1708]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.28      0.41      1971
#            1       0.55      0.90      0.68      1890
#
#     accuracy                           0.59      3861
#    macro avg       0.65      0.59      0.55      3861
# weighted avg       0.65      0.59      0.54      3861
#
# DecisionTreeClassifier()
# 0.8184408184408184
# [[1596  375]
#  [ 326 1564]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82      1971
#            1       0.81      0.83      0.82      1890
#
#     accuracy                           0.82      3861
#    macro avg       0.82      0.82      0.82      3861
# weighted avg       0.82      0.82      0.82      3861
#
# SVC()
# 0.7904687904687905
# [[1596  375]
#  [ 434 1456]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.81      0.80      1971
#            1       0.80      0.77      0.78      1890
#
#     accuracy                           0.79      3861
#    macro avg       0.79      0.79      0.79      3861
# weighted avg       0.79      0.79      0.79      3861
#
# RandomForestClassifier()
# 0.8438228438228438
# [[1682  289]
#  [ 314 1576]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.85      1971
#            1       0.85      0.83      0.84      1890
#
#     accuracy                           0.84      3861
#    macro avg       0.84      0.84      0.84      3861
# weighted avg       0.84      0.84      0.84      3861
#
# ExtraTreesClassifier()
# 0.8614348614348615
# [[1687  284]
#  [ 251 1639]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.86      1971
#            1       0.85      0.87      0.86      1890
#
#     accuracy                           0.86      3861
#    macro avg       0.86      0.86      0.86      3861
# weighted avg       0.86      0.86      0.86      3861
#
# AdaBoostClassifier()
# 0.725977725977726
# [[1467  504]
#  [ 554 1336]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.74      0.73      1971
#            1       0.73      0.71      0.72      1890
#
#     accuracy                           0.73      3861
#    macro avg       0.73      0.73      0.73      3861
# weighted avg       0.73      0.73      0.73      3861
#
# GradientBoostingClassifier()
# 0.7277907277907278
# [[1462  509]
#  [ 542 1348]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.74      0.74      1971
#            1       0.73      0.71      0.72      1890
#
#     accuracy                           0.73      3861
#    macro avg       0.73      0.73      0.73      3861
# weighted avg       0.73      0.73      0.73      3861

# %%
from sklearn.model_selection import cross_val_score

# %%
for i in models:
    print('accuracy score of',i,'is',accuracy_score(y_test,pred))
    cvs=cross_val_score(i,x,y,cv=5)
    print('cross validation score for',i,'model is:',cvs.mean())
    print(' ')
# Out:
# accuracy score of LogisticRegression() is 0.7277907277907278
# cross validation score for LogisticRegression() model is: 0.4483263681087234
#
# accuracy score of GaussianNB() is 0.7277907277907278
# cross validation score for GaussianNB() model is: 0.318379495876581
#
# accuracy score of DecisionTreeClassifier() is 0.7277907277907278
# cross validation score for DecisionTreeClassifier() model is: 0.6199068625807842
#
# accuracy score of SVC() is 0.7277907277907278
# cross validation score for SVC() model is: 0.5111923745814145
#
# accuracy score of RandomForestClassifier() is 0.7277907277907278
# cross validation score for RandomForestClassifier() model is: 0.620375418509892
#
# accuracy score of ExtraTreesClassifier() is 0.7277907277907278
# cross validation score for ExtraTreesClassifier() model is: 0.6340519911060136
#
# accuracy score of AdaBoostClassifier() is 0.7277907277907278
# cross validation score for AdaBoostClassifier() model is: 0.4159156514772528
#
# accuracy score of GradientBoostingClassifier() is 0.7277907277907278
# cross validation score for GradientBoostingClassifier() model is: 0.4201097041749976

# %%
from sklearn.metrics import plot_roc_curve

dis= plot_roc_curve(rf,x_test,y_test)
plot_roc_curve(lr,x_test,y_test)
plot_roc_curve(dtc,x_test,y_test)
plot_roc_curve(svc,x_test,y_test)
plot_roc_curve(gb,x_test,y_test)
plot_roc_curve(et,x_test,y_test)
plot_roc_curve(ada,x_test,y_test)
plot_roc_curve(gbc,x_test,y_test)

# %%
from sklearn.model_selection import GridSearchCV

# %%
#extra trees as it gives best auc and accurcacy acore

# %%
params = {'n_estimators':[100,200,300,400,500],
         'criterion':['gini','entropy'],
         'max_features':['sqrt','log2']}

# %%
GCV=GridSearchCV(et,params,cv=5,scoring='accuracy',n_jobs=-1)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [100, 200, 300, 400, 500]},
#              scoring='accuracy')

# %%
GCV.best_estimator_
# Out:
# ExtraTreesClassifier(criterion='entropy', max_features='log2', n_estimators=300)

# %%
GCV.best_params_
# Out:
# {'criterion': 'entropy', 'max_features': 'log2', 'n_estimators': 300}

# %%
pred=GCV.best_estimator_.predict(x_test)

# %%
accuracy_score(y_test,pred)
# Out:
# 0.8616938616938616

# %%
print("accuracy score",round(accuracy_score(y_test,pred)*100,2))
# Out:
# accuracy score 86.17

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,pred)
sns.heatmap(confusion_matrix(y_test,pred),annot=True,fmt='d')
# Out:
# <AxesSubplot:>

# %%
plot_roc_curve(GCV.best_estimator_,x_test,y_test)
plt.title("ROC AUC PLOT")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import joblib

# %%
joblib.dump(GCV.best_estimator_,'weather.pkl')
# Out:
# ['weather.pkl']

# %% [markdown]
# predict the rainfalL.
# REGRESSION  MODEL

# %%
df.head()
# Out:
#   Location  MinTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0   Albury     13.4       0.6          4.6       8.7           W
# 1   Albury      7.4       0.0          4.6       8.7         WNW
# 2   Albury     12.9       0.0          4.6       8.7         WSW
# 3   Albury      9.2       0.0          4.6       8.7          NE
# 4   Albury     17.5       1.0          4.6       8.7           W
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           44.0          W        WNW          20.0  ...         22.0
# 1           44.0        NNW        WSW           4.0  ...         25.0
# 2           46.0          W        WSW          19.0  ...         30.0
# 3           24.0         SE          E          11.0  ...         16.0
# 4           41.0        ENE         NW           7.0  ...         33.0
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp3pm  RainToday  RainTomorrow  year  \
# 0       1007.1       8.0       5.0     21.8         No            No  2008
# 1       1007.8       5.0       5.0     24.3         No            No  2008
# 2       1008.7       5.0       2.0     23.2         No            No  2008
# 3       1012.8       5.0       5.0     26.5         No            No  2008
# 4       1006.0       7.0       8.0     29.7         No            No  2008
#
#   month  day
# 0    12    1
# 1    12    2
# 2    12    3
# 3    12    4
# 4    12    5
#
# [5 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# Location         0
# MinTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# year             0
# month            0
# day              0
# dtype: int64

# %%
df.dtypes
# Out:
# Location          object
# MinTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# year               int64
# month              int64
# day                int64
# dtype: object

# %%
df.corr()
# Out:
#                 MinTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# MinTemp        1.000000  0.085765     0.262887  0.031722       0.230200
# Rainfall       0.085765  1.000000     0.020252 -0.166957       0.082628
# Evaporation    0.262887  0.020252     1.000000  0.217816       0.147367
# Sunshine       0.031722 -0.166957     0.217816  1.000000      -0.034623
# WindGustSpeed  0.230200  0.082628     0.147367 -0.034623       1.000000
# WindSpeed9am   0.136643  0.048726     0.133320 -0.068995       0.606090
# WindSpeed3pm   0.178137  0.021594     0.121595 -0.004683       0.639042
# Humidity9am   -0.130711  0.227587    -0.235151 -0.316515      -0.271865
# Humidity3pm    0.079143  0.234955    -0.169831 -0.421006      -0.093637
# Pressure3pm   -0.423261 -0.031261    -0.189711 -0.032167      -0.372553
# Cloud9am       0.078412  0.176615    -0.078895 -0.489100       0.019763
# Cloud3pm       0.022147  0.142066    -0.119121 -0.511608       0.070237
# Temp3pm        0.685859 -0.090649     0.318211  0.376915       0.102066
# year           0.044200  0.004491     0.128610  0.134540      -0.049612
# month         -0.245872 -0.016258     0.012519 -0.011949       0.051063
# day            0.009448 -0.013029     0.015478  0.003420      -0.002454
#
#                WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# MinTemp            0.136643      0.178137    -0.130711     0.079143
# Rainfall           0.048726      0.021594     0.227587     0.234955
# Evaporation        0.133320      0.121595    -0.235151    -0.169831
# Sunshine          -0.068995     -0.004683    -0.316515    -0.421006
# WindGustSpeed      0.606090      0.639042    -0.271865    -0.093637
# WindSpeed9am       1.000000      0.560340    -0.358391    -0.110545
# WindSpeed3pm       0.560340      1.000000    -0.250930    -0.091056
# Humidity9am       -0.358391     -0.250930     1.000000     0.633285
# Humidity3pm       -0.110545     -0.091056     0.633285     1.000000
# Pressure3pm       -0.139429     -0.208694     0.173934     0.070454
# Cloud9am          -0.006931     -0.000171     0.399198     0.409267
# Cloud3pm           0.047359     -0.001803     0.294970     0.420823
# Temp3pm           -0.002279      0.066078    -0.382542    -0.491446
# year              -0.089009     -0.050990     0.099752    -0.029040
# month              0.038480      0.049475    -0.115542    -0.074265
# day               -0.003054     -0.009059     0.003803     0.012553
#
#                Pressure3pm  Cloud9am  Cloud3pm   Temp3pm      year     month  \
# MinTemp          -0.423261  0.078412  0.022147  0.685859  0.044200 -0.245872
# Rainfall         -0.031261  0.176615  0.142066 -0.090649  0.004491 -0.016258
# Evaporation      -0.189711 -0.078895 -0.119121  0.318211  0.128610  0.012519
# Sunshine         -0.032167 -0.489100 -0.511608  0.376915  0.134540 -0.011949
# WindGustSpeed    -0.372553  0.019763  0.070237  0.102066 -0.049612  0.051063
# WindSpeed9am     -0.139429 -0.006931  0.047359 -0.002279 -0.089009  0.038480
# WindSpeed3pm     -0.208694 -0.000171 -0.001803  0.066078 -0.050990  0.049475
# Humidity9am       0.173934  0.399198  0.294970 -0.382542  0.099752 -0.115542
# Humidity3pm       0.070454  0.409267  0.420823 -0.491446 -0.029040 -0.074265
# Pressure3pm       1.000000 -0.011209 -0.025561 -0.369933  0.015363  0.002163
# Cloud9am         -0.011209  1.000000  0.579788 -0.269166  0.015865 -0.011073
# Cloud3pm         -0.025561  0.579788  1.000000 -0.292183  0.002261  0.003532
# Temp3pm          -0.369933 -0.269166 -0.292183  1.000000  0.131771 -0.176243
# year              0.015363  0.015865  0.002261  0.131771  1.000000 -0.090394
# month             0.002163 -0.011073  0.003532 -0.176243 -0.090394  1.000000
# day              -0.011690 -0.008278 -0.000207  0.013207 -0.003836  0.004386
#
#                     day
# MinTemp        0.009448
# Rainfall      -0.013029
# Evaporation    0.015478
# Sunshine       0.003420
# WindGustSpeed -0.002454
# WindSpeed9am  -0.003054
# WindSpeed3pm  -0.009059
# Humidity9am    0.003803
# Humidity3pm    0.012553
# Pressure3pm   -0.011690
# Cloud9am      -0.008278
# Cloud3pm      -0.000207
# Temp3pm        0.013207
# year          -0.003836
# month          0.004386
# day            1.000000

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Location', 'MinTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp3pm', 'RainToday',
#        'RainTomorrow', 'year', 'month', 'day'],
#       dtype='object')

# %%
cat
# Out:
# ['Location',
#  'WindGustDir',
#  'WindDir9am',
#  'WindDir3pm',
#  'RainToday',
#  'RainTomorrow']

# %%
cont
# Out:
# ['MinTemp',
#  'Evaporation',
#  'Sunshine',
#  'WindGustSpeed',
#  'WindSpeed9am',
#  'WindSpeed3pm',
#  'Humidity9am',
#  'Humidity3pm',
#  'Pressure3pm',
#  'Cloud9am',
#  'Cloud3pm',
#  'Temp3pm',
#  'year',
#  'month',
#  'day']

# %%
v=df[cont]
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scaled=sc.fit_transform(v)
VIF= pd.DataFrame()
VIF['features']=v.columns
VIF['vif']= [variance_inflation_factor(scaled,i) for i in range(len(v.columns))]
VIF
# Out:
#          features       vif
# 0         MinTemp  4.517941
# 1     Evaporation  1.198866
# 2        Sunshine  1.682756
# 3   WindGustSpeed  2.269092
# 4    WindSpeed9am  1.980522
# 5    WindSpeed3pm  1.859500
# 6     Humidity9am  2.296190
# 7     Humidity3pm  3.632213
# 8     Pressure3pm  1.427144
# 9        Cloud9am  1.845110
# 10       Cloud3pm  1.770663
# 11        Temp3pm  5.733895
# 12           year  1.098011
# 13          month  1.123297
# 14            day  1.001587

# %%
v=df[cont]
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scaled=sc.fit_transform(v)
VIF= pd.DataFrame()
VIF['features']=v.columns
VIF['vif']= [variance_inflation_factor(scaled,i) for i in range(len(v.columns))]
VIF
# Out:
#          features       vif
# 0         MinTemp  4.517941
# 1     Evaporation  1.198866
# 2        Sunshine  1.682756
# 3   WindGustSpeed  2.269092
# 4    WindSpeed9am  1.980522
# 5    WindSpeed3pm  1.859500
# 6     Humidity9am  2.296190
# 7     Humidity3pm  3.632213
# 8     Pressure3pm  1.427144
# 9        Cloud9am  1.845110
# 10       Cloud3pm  1.770663
# 11        Temp3pm  5.733895
# 12           year  1.098011
# 13          month  1.123297
# 14            day  1.001587

# %%
v=df[cont]
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scaled=sc.fit_transform(v)
VIF= pd.DataFrame()
VIF['features']=v.columns
VIF['vif']= [variance_inflation_factor(scaled,i) for i in range(len(v.columns))]
VIF
# Out:
#          features       vif
# 0         MinTemp  4.517941
# 1     Evaporation  1.198866
# 2        Sunshine  1.682756
# 3   WindGustSpeed  2.269092
# 4    WindSpeed9am  1.980522
# 5    WindSpeed3pm  1.859500
# 6     Humidity9am  2.296190
# 7     Humidity3pm  3.632213
# 8     Pressure3pm  1.427144
# 9        Cloud9am  1.845110
# 10       Cloud3pm  1.770663
# 11        Temp3pm  5.733895
# 12           year  1.098011
# 13          month  1.123297
# 14            day  1.001587

# %%
df.head()
# Out:
#   Location  MinTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0   Albury     13.4       0.6          4.6       8.7           W
# 1   Albury      7.4       0.0          4.6       8.7         WNW
# 2   Albury     12.9       0.0          4.6       8.7         WSW
# 3   Albury      9.2       0.0          4.6       8.7          NE
# 4   Albury     17.5       1.0          4.6       8.7           W
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           44.0          W        WNW          20.0  ...         22.0
# 1           44.0        NNW        WSW           4.0  ...         25.0
# 2           46.0          W        WSW          19.0  ...         30.0
# 3           24.0         SE          E          11.0  ...         16.0
# 4           41.0        ENE         NW           7.0  ...         33.0
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp3pm  RainToday  RainTomorrow  year  \
# 0       1007.1       8.0       5.0     21.8         No            No  2008
# 1       1007.8       5.0       5.0     24.3         No            No  2008
# 2       1008.7       5.0       2.0     23.2         No            No  2008
# 3       1012.8       5.0       5.0     26.5         No            No  2008
# 4       1006.0       7.0       8.0     29.7         No            No  2008
#
#   month  day
# 0    12    1
# 1    12    2
# 2    12    3
# 3    12    4
# 4    12    5
#
# [5 rows x 22 columns]

# %%
df.corr()
# Out:
#                 MinTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# MinTemp        1.000000  0.085765     0.262887  0.031722       0.230200
# Rainfall       0.085765  1.000000     0.020252 -0.166957       0.082628
# Evaporation    0.262887  0.020252     1.000000  0.217816       0.147367
# Sunshine       0.031722 -0.166957     0.217816  1.000000      -0.034623
# WindGustSpeed  0.230200  0.082628     0.147367 -0.034623       1.000000
# WindSpeed9am   0.136643  0.048726     0.133320 -0.068995       0.606090
# WindSpeed3pm   0.178137  0.021594     0.121595 -0.004683       0.639042
# Humidity9am   -0.130711  0.227587    -0.235151 -0.316515      -0.271865
# Humidity3pm    0.079143  0.234955    -0.169831 -0.421006      -0.093637
# Pressure3pm   -0.423261 -0.031261    -0.189711 -0.032167      -0.372553
# Cloud9am       0.078412  0.176615    -0.078895 -0.489100       0.019763
# Cloud3pm       0.022147  0.142066    -0.119121 -0.511608       0.070237
# Temp3pm        0.685859 -0.090649     0.318211  0.376915       0.102066
# year           0.044200  0.004491     0.128610  0.134540      -0.049612
# month         -0.245872 -0.016258     0.012519 -0.011949       0.051063
# day            0.009448 -0.013029     0.015478  0.003420      -0.002454
#
#                WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# MinTemp            0.136643      0.178137    -0.130711     0.079143
# Rainfall           0.048726      0.021594     0.227587     0.234955
# Evaporation        0.133320      0.121595    -0.235151    -0.169831
# Sunshine          -0.068995     -0.004683    -0.316515    -0.421006
# WindGustSpeed      0.606090      0.639042    -0.271865    -0.093637
# WindSpeed9am       1.000000      0.560340    -0.358391    -0.110545
# WindSpeed3pm       0.560340      1.000000    -0.250930    -0.091056
# Humidity9am       -0.358391     -0.250930     1.000000     0.633285
# Humidity3pm       -0.110545     -0.091056     0.633285     1.000000
# Pressure3pm       -0.139429     -0.208694     0.173934     0.070454
# Cloud9am          -0.006931     -0.000171     0.399198     0.409267
# Cloud3pm           0.047359     -0.001803     0.294970     0.420823
# Temp3pm           -0.002279      0.066078    -0.382542    -0.491446
# year              -0.089009     -0.050990     0.099752    -0.029040
# month              0.038480      0.049475    -0.115542    -0.074265
# day               -0.003054     -0.009059     0.003803     0.012553
#
#                Pressure3pm  Cloud9am  Cloud3pm   Temp3pm      year     month  \
# MinTemp          -0.423261  0.078412  0.022147  0.685859  0.044200 -0.245872
# Rainfall         -0.031261  0.176615  0.142066 -0.090649  0.004491 -0.016258
# Evaporation      -0.189711 -0.078895 -0.119121  0.318211  0.128610  0.012519
# Sunshine         -0.032167 -0.489100 -0.511608  0.376915  0.134540 -0.011949
# WindGustSpeed    -0.372553  0.019763  0.070237  0.102066 -0.049612  0.051063
# WindSpeed9am     -0.139429 -0.006931  0.047359 -0.002279 -0.089009  0.038480
# WindSpeed3pm     -0.208694 -0.000171 -0.001803  0.066078 -0.050990  0.049475
# Humidity9am       0.173934  0.399198  0.294970 -0.382542  0.099752 -0.115542
# Humidity3pm       0.070454  0.409267  0.420823 -0.491446 -0.029040 -0.074265
# Pressure3pm       1.000000 -0.011209 -0.025561 -0.369933  0.015363  0.002163
# Cloud9am         -0.011209  1.000000  0.579788 -0.269166  0.015865 -0.011073
# Cloud3pm         -0.025561  0.579788  1.000000 -0.292183  0.002261  0.003532
# Temp3pm          -0.369933 -0.269166 -0.292183  1.000000  0.131771 -0.176243
# year              0.015363  0.015865  0.002261  0.131771  1.000000 -0.090394
# month             0.002163 -0.011073  0.003532 -0.176243 -0.090394  1.000000
# day              -0.011690 -0.008278 -0.000207  0.013207 -0.003836  0.004386
#
#                     day
# MinTemp        0.009448
# Rainfall      -0.013029
# Evaporation    0.015478
# Sunshine       0.003420
# WindGustSpeed -0.002454
# WindSpeed9am  -0.003054
# WindSpeed3pm  -0.009059
# Humidity9am    0.003803
# Humidity3pm    0.012553
# Pressure3pm   -0.011690
# Cloud9am      -0.008278
# Cloud3pm      -0.000207
# Temp3pm        0.013207
# year          -0.003836
# month          0.004386
# day            1.000000

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
X=df.drop('Rainfall',axis=1)
Y=df['Rainfall']

# %%
X.shape
# Out:
# (8425, 21)

# %%
Y.shape
# Out:
# (8425,)

# %%
cont=[i for i in X.columns if X[i].dtypes!='O']

# %%
for i in cont:
    sns.boxplot(X[i])
    plt.show()

# %%
df[cont].skew()
# Out:
# MinTemp          -0.090519
# Evaporation      14.064000
# Sunshine         -1.189333
# WindGustSpeed     0.786153
# WindSpeed9am      0.962761
# WindSpeed3pm      0.492365
# Humidity9am      -0.256965
# Humidity3pm       0.118776
# Pressure3pm      -0.015018
# Cloud9am         -0.514801
# Cloud3pm         -0.457713
# Temp3pm           0.400388
# year              0.418663
# month             0.039388
# day               0.004260
# dtype: float64

# %%
for i in cont:
    IQR=X[i].quantile(.75)-X[i].quantile(.25)
    lower=X[i].quantile(.25)-(1.5 * IQR)
    upper=X[i].quantile(.75)+(1.5*IQR)
    X[i]=np.where(X[i]<lower,lower,X[i])
    X[i]=np.where(X[i]>upper,upper,X[i])

# %%
X[cont].skew()
# Out:
# MinTemp         -0.090519
# Evaporation      0.062973
# Sunshine        -0.110856
# WindGustSpeed    0.539607
# WindSpeed9am     0.739837
# WindSpeed3pm     0.332888
# Humidity9am     -0.241260
# Humidity3pm      0.118776
# Pressure3pm      0.009366
# Cloud9am        -0.514801
# Cloud3pm        -0.457713
# Temp3pm          0.360232
# year             0.418663
# month            0.039388
# day              0.004260
# dtype: float64

# %% [markdown]
# # Tranformation

# %%
from sklearn.preprocessing import power_transform
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
for i in cont:
    trans=power_transform(df[cont])
    X[i]=sc.fit_transform(trans)

# %%
X.head()
# Out:
#   Location   MinTemp  Evaporation  Sunshine WindGustDir  WindGustSpeed  \
# 0   Albury  0.040870     0.040870  0.040870           W       0.040870
# 1   Albury -1.076476    -1.076476 -1.076476         WNW      -1.076476
# 2   Albury -0.051970    -0.051970 -0.051970         WSW      -0.051970
# 3   Albury -0.740439    -0.740439 -0.740439          NE      -0.740439
# 4   Albury  0.800709     0.800709  0.800709           W       0.800709
#
#   WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  ...  Humidity3pm  \
# 0          W        WNW      0.040870      0.040870  ...     0.040870
# 1        NNW        WSW     -1.076476     -1.076476  ...    -1.076476
# 2          W        WSW     -0.051970     -0.051970  ...    -0.051970
# 3         SE          E     -0.740439     -0.740439  ...    -0.740439
# 4        ENE         NW      0.800709      0.800709  ...     0.800709
#
#    Pressure3pm  Cloud9am  Cloud3pm   Temp3pm  RainToday RainTomorrow  \
# 0     0.040870  0.040870  0.040870  0.040870         No           No
# 1    -1.076476 -1.076476 -1.076476 -1.076476         No           No
# 2    -0.051970 -0.051970 -0.051970 -0.051970         No           No
# 3    -0.740439 -0.740439 -0.740439 -0.740439         No           No
# 4     0.800709  0.800709  0.800709  0.800709         No           No
#
#        year     month       day
# 0  0.040870  0.040870  0.040870
# 1 -1.076476 -1.076476 -1.076476
# 2 -0.051970 -0.051970 -0.051970
# 3 -0.740439 -0.740439 -0.740439
# 4  0.800709  0.800709  0.800709
#
# [5 rows x 21 columns]

# %% [raw]
# ENocding

# %%
X=pd.get_dummies(X,drop_first=True)

# %%
X.shape
# Out:
# (8425, 73)

# %%
Y.shape
# Out:
# (8425,)

# %% [markdown]
# # machine learning

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import ExtraTreesRegressor

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
df.dtypes
# Out:
# Location          object
# MinTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# year               int64
# month              int64
# day                int64
# dtype: object

# %%
LR= LinearRegression()

# %%
for i in range(0,200):
    x_train,x_test,y_train,y_test= train_test_split(X,Y,random_state=i,test_size=.2)
    LR.fit(x_train,y_train)
    train_pred=LR.predict(x_train)
    test_pred=LR.predict(x_test)
    if round(r2_score(y_test,test_pred),2)==round(r2_score(y_train,train_pred),2):
        print("At random state ", i, "The model performance very well")
        print("At random state: ",i)
        print("Test R2 score is: ", round(r2_score(y_test,test_pred),2))
        print('Train R2 score is: ', round(r2_score(y_train,train_pred),2))
        print('X'*50,'\n')
# Out:
# At random state  27 The model performance very well
# At random state:  27
# Test R2 score is:  0.25
# Train R2 score is:  0.25
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  52 The model performance very well
# At random state:  52
# Test R2 score is:  0.25
# Train R2 score is:  0.25
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  68 The model performance very well
# At random state:  68
# Test R2 score is:  0.25
# Train R2 score is:  0.25
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  76 The model performance very well
# At random state:  76
# Test R2 score is:  0.25
# Train R2 score is:  0.25
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  85 The model performance very well
# At random state:  85
# Test R2 score is:  0.25
# Train R2 score is:  0.25
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  97 The model performance very well
# At random state:  97
# Test R2 score is:  0.25
# Train R2 score is:  0.25
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  153 The model performance very well
# At random state:  153
# Test R2 score is:  0.25
# Train R2 score is:  0.25
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  159 The model performance very well
# At random state:  159
# Test R2 score is:  0.25
# Train R2 score is:  0.25
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  170 The model performance very well
# At random state:  170
# Test R2 score is:  0.25
# Train R2 score is:  0.25
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  173 The model performance very well
# At random state:  173
# Test R2 score is:  0.25
# Train R2 score is:  0.25
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  182 The model performance very well
# At random state:  182
# Test R2 score is:  0.25
# Train R2 score is:  0.25
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  184 The model performance very well
# At random state:  184
# Test R2 score is:  0.25
# Train R2 score is:  0.25
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX

# %%
#select randon state 27

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=.30,random_state=27)

# %%
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
LR = LinearRegression()
lr.fit(x_train,y_train)
print(lr.score(x_train,y_train))
lr_predict=lr.predict(x_test)
# Out:
# 0.2650161611862648

# %%
print("mean squared error:",mean_squared_error(lr_predict,y_test))
print("mean absolute error",mean_absolute_error(lr_predict,y_test))
print("r2_score",r2_score(lr_predict,y_test))
# Out:
# mean squared error: 99.03555746012601
# mean absolute error 3.5274024991537205
# r2_score -2.634073976166563

# %%
from sklearn.linear_model import Ridge
r=Ridge()
r.fit(x_train,y_train)
print(r.score(x_train,y_train))
r_predict=r.predict(x_test)
# Out:
# 0.26501538277700687

# %%
print("mean squared error:", mean_squared_error(r_predict,y_test))
print("mean absolute error:",mean_absolute_error(r_predict,y_test))
print("r2_Score:",r2_score(r_predict,y_test))
# Out:
# mean squared error: 99.0330893363286
# mean absolute error: 3.524968391956309
# r2_Score: -2.6405881494640213

# %%
LR_model= LinearRegression()
RD_model= Ridge()
LS_model= Lasso()
DT_model= DecisionTreeRegressor()
SV_model= SVR()
KNR_model= KNeighborsRegressor()
RFR_model= RandomForestRegressor()

Elastic_model= ElasticNet()

ADA_model=AdaBoostRegressor()
GB_model= GradientBoostingRegressor()

model=[LR_model,RD_model,LS_model,DT_model,SV_model,KNR_model,RFR_model,Elastic_model,ADA_model,GB_model]

# %%
for m in model:
    m.fit(x_train,y_train)
    print('mean_absolute_error of ',m ,'model', mean_absolute_error(y_test,m.predict(x_test)))
    print('mean_square_error of',m,'model' , mean_squared_error(y_test,m.predict(x_test)))
    print('R2 Score of',m,'model', r2_score(y_test,m.predict(x_test) )*100)
    print('X' * 50, '\n\n')
# Out:
# mean_absolute_error of  LinearRegression() model 3.5274024991537205
# mean_square_error of LinearRegression() model 99.03555746012601
# R2 Score of LinearRegression() model 22.097710123394243
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
#
# mean_absolute_error of  Ridge() model 3.524968391956309
# mean_square_error of Ridge() model 99.0330893363286
# R2 Score of Ridge() model 22.09965157251059
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
#
# mean_absolute_error of  Lasso() model 3.2023583214986995
# mean_square_error of Lasso() model 108.26226121047512
# R2 Score of Lasso() model 14.839899205788631
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
#
# mean_absolute_error of  DecisionTreeRegressor() model 2.2107594936708863
# mean_square_error of DecisionTreeRegressor() model 89.03090981012659
# R2 Score of DecisionTreeRegressor() model 29.967458942219814
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
#
# mean_absolute_error of  SVR() model 2.317377705960711
# mean_square_error of SVR() model 112.06357763832446
# R2 Score of SVR() model 11.84974837643371
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
#
# mean_absolute_error of  KNeighborsRegressor() model 2.8787974683544304
# mean_square_error of KNeighborsRegressor() model 100.1318579113924
# R2 Score of KNeighborsRegressor() model 21.235350000053764
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
#
# mean_absolute_error of  RandomForestRegressor() model 2.0227911392405065
# mean_square_error of RandomForestRegressor() model 66.61184467246835
# R2 Score of RandomForestRegressor() model 47.6025039291634
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
#
# mean_absolute_error of  ElasticNet() model 3.6180290484751527
# mean_square_error of ElasticNet() model 113.71656221598815
# R2 Score of ElasticNet() model 10.549495345772863
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
#
# mean_absolute_error of  AdaBoostRegressor() model 13.686055260683244
# mean_square_error of AdaBoostRegressor() model 255.26863947413221
# R2 Score of AdaBoostRegressor() model -100.796684127589
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
#
# mean_absolute_error of  GradientBoostingRegressor() model 2.41067150172656
# mean_square_error of GradientBoostingRegressor() model 72.65017622194445
# R2 Score of GradientBoostingRegressor() model 42.85269621562844
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX

# %% [markdown]
# # CROSS VALIDATION

# %%
from sklearn.model_selection import cross_val_score

# %%
for i in model:
    print('Root mean_square of ',i, 'model',np.sqrt(mean_squared_error(y_test,i.predict(x_test))))
    score=cross_val_score(i,X,Y,cv=10, scoring='neg_mean_squared_error').mean()
    print("cross Validation score of root mean square ",i ," is ",np.sqrt(-score))
    print('*'*50)
# Out:
# Root mean_square of  LinearRegression() model 9.951661040254839
# cross Validation score of root mean square  LinearRegression()  is  17283025368609.377
# **************************************************
# Root mean_square of  Ridge() model 9.951537033862087
# cross Validation score of root mean square  Ridge()  is  9.065306533599582
# **************************************************
# Root mean_square of  Lasso() model 10.404915242829954
# cross Validation score of root mean square  Lasso()  is  9.435054167285308
# **************************************************
# Root mean_square of  DecisionTreeRegressor() model 9.43561920650291
# cross Validation score of root mean square  DecisionTreeRegressor()  is  9.270988502091216
# **************************************************
# Root mean_square of  SVR() model 10.586008579173004
# cross Validation score of root mean square  SVR()  is  9.59922495760926
# **************************************************
# Root mean_square of  KNeighborsRegressor() model 10.006590723687683
# cross Validation score of root mean square  KNeighborsRegressor()  is  9.277121845751253
# **************************************************
# Root mean_square of  RandomForestRegressor() model 8.16160797101088
# cross Validation score of root mean square  RandomForestRegressor()  is  7.539884111093897
# **************************************************
# Root mean_square of  ElasticNet() model 10.66379680113927
# cross Validation score of root mean square  ElasticNet()  is  9.714317140205665
# **************************************************
# Root mean_square of  AdaBoostRegressor() model 15.977128636714802
# cross Validation score of root mean square  AdaBoostRegressor()  is  17.479587380588523
# **************************************************
# Root mean_square of  GradientBoostingRegressor() model 8.523507272358279
# cross Validation score of root mean square  GradientBoostingRegressor()  is  8.109889875387985
# **************************************************

# %%
n_estimator= [200, 400, 600, 800, 1000]  # no of tree in Random forest, default is 100
max_features= ['auto','sqrt','log2']  # mini no of features to create Decission Tree
max_depth=[10, 64, 118, 173, 227, 282, 336]  #  Max depth of decision tree
min_samples_split= [1,2,3]   # mini no of sample rerquired to split node
min_samples_leaf= [1,3,4,6,7,9]  #mini no of sample required at each leaf node

param_grid= {'n_estimators': n_estimator,
             'max_features':max_features,
             'max_depth':max_depth,
             'min_samples_split':min_samples_split,
             'min_samples_leaf':min_samples_leaf,
             }
param_grid
# Out:
# {'n_estimators': [200, 400, 600, 800, 1000],
#  'max_features': ['auto', 'sqrt', 'log2'],
#  'max_depth': [10, 64, 118, 173, 227, 282, 336],
#  'min_samples_split': [1, 2, 3],
#  'min_samples_leaf': [1, 3, 4, 6, 7, 9]}

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
grid_search=RandomizedSearchCV(estimator=RFR_model,param_distributions=param_grid,cv=5,n_jobs=-1,verbose=2)
grid_search.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#                    param_distributions={'max_depth': [10, 64, 118, 173, 227,
#                                                       282, 336],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [1, 3, 4, 6, 7, 9],
#                                         'min_samples_split': [1, 2, 3],
#                                         'n_estimators': [200, 400, 600, 800,
#                                                          1000]},
#                    verbose=2)

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(max_depth=282, max_features='sqrt', n_estimators=400)

# %%
grid_search.best_params_
# Out:
# {'n_estimators': 400,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_features': 'sqrt',
#  'max_depth': 282}

# %%
GCV_pred=grid_search.best_estimator_.predict(x_test)

np.sqrt(mean_squared_error(y_test,GCV_pred))
# Out:
# 8.15203674651585

# %%
import joblib
joblib.dump(grid_search.best_estimator_,"Rainfall_Prediction_in_rm.pkl")
# Out:
# ['Rainfall_Prediction_in_rm.pkl']
